# %%
import pandas as pd
df = pd.read_csv("zillow/BreakEven_2017-03.csv")

# %%
df.columns
# Out:
# Index(['RegionType', 'RegionID', 'RegionName', 'SizeRank', 'City',
#        'CountyName', 'Metro', 'CBSATitle', 'StateName', 'BEPropCount',
#        'SampleRate', 'MedBE', 'Breakeven', 'MedPR'],
#       dtype='object')

# %%
df[df['StateName']=='MA'].sort_values("Breakeven").plot(kind='hist')
# Out:
#          RegionType  RegionID               RegionName  SizeRank  \
# 24040  Neighborhood    155281                 Old Hill      2696
# 27144  Neighborhood    274508             Metro Center      1637
# 27997  Neighborhood    276436   Maple High-Six Corners      2148
# 10431           Zip     58270                    01105      6915
# 24031  Neighborhood    154783           Indian Orchard      1304
# 10440           Zip     58287                    01151      8174
# 24047  Neighborhood    155852               Upper Hill      1543
# 10435           Zip     58274                    01109      3932
# 24033  Neighborhood    154868          Liberty Heights       690
# 24041  Neighborhood    155354               Pine Point      1029
# 10430           Zip     58269                    01104      4538
# 24028  Neighborhood    154455         East Springfield      1559
# 6004           City     31264                   Dracut      1541
# ...
